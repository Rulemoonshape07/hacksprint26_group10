# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

df4 = pd.read_csv(r"C:\Users\vidhi\analytics_challenge\data\raw\annex4.csv")

df4.head()
# Out:
#          Item Code                 Item Name  Loss Rate (%)
# 0  102900005115168          Niushou Shengcai           4.39
# 1  102900005115199         Sichuan Red Cedar          10.46
# 2  102900005115250  Xixia Black Mushroom (1)          10.80
# 3  102900005115625     Local Xiaomao Cabbage           0.18
# 4  102900005115748              White Caitai           8.78

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Loss Rate (%)  251 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
df4.describe(include="all")
# Out:
#            Item Code        Item Name  Loss Rate (%)
# count   2.510000e+02              251     251.000000
# unique           NaN              247            NaN
# top              NaN  Chinese Cabbage            NaN
# freq             NaN                2            NaN
# mean    1.031908e+14              NaN       9.426693
# std     1.048400e+12              NaN       5.211027
# min     1.029000e+14              NaN       0.000000
# 25%     1.029000e+14              NaN       8.225000
# 50%     1.029000e+14              NaN       9.430000
# 75%     1.029000e+14              NaN      11.130000
# max     1.069740e+14              NaN      29.250000

# %%
df4_clean = df4.copy()

df4_clean.columns = (
    df4_clean.columns
    .str.lower()
    .str.replace(" ", "_")
)

df4_clean.head()
# Out:
#          item_code                 item_name  loss_rate_(%)
# 0  102900005115168          Niushou Shengcai           4.39
# 1  102900005115199         Sichuan Red Cedar          10.46
# 2  102900005115250  Xixia Black Mushroom (1)          10.80
# 3  102900005115625     Local Xiaomao Cabbage           0.18
# 4  102900005115748              White Caitai           8.78

# %%
df4_clean = df4.copy()

df4_clean.columns = (
    df4_clean.columns
    .str.lower()
    .str.replace(" ", "_")
)

df4_clean.head()
# Out:
#          item_code                 item_name  loss_rate_(%)
# 0  102900005115168          Niushou Shengcai           4.39
# 1  102900005115199         Sichuan Red Cedar          10.46
# 2  102900005115250  Xixia Black Mushroom (1)          10.80
# 3  102900005115625     Local Xiaomao Cabbage           0.18
# 4  102900005115748              White Caitai           8.78

# %%
df4_clean.isna().sum()
# Out:
# item_code        0
# item_name        0
# loss_rate_(%)    0
# dtype: int64

# %%
df4_clean.to_csv("../data/processed/annex4_cleaned.csv", index=False)

# %%
annex1 = pd.read_csv("../data/processed/annex1_cleaned.csv")
annex2 = pd.read_csv("../data/processed/annex2_cleaned.csv")
annex3 = pd.read_csv("../data/processed/annex3_cleaned.csv")
annex4 = pd.read_csv("../data/processed/annex4_cleaned.csv")

# %%
df_final = annex2.merge(
    annex1,
    on="item_code",
    how="left"
)

# %%
df_final = df_final.merge(
    annex3,
    on="item_code",
    how="left"
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_final = df_final.merge(
#       2     annex3,
#       3     on="item_code",
#       4     how="left"
#       5 )
#
# File c:\Users\vidhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10859, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10840 @Substitution("")
#   10841 @Appender(_merge_doc, indents=2)
#   10842 def merge(
#    (...)  10855     validate: MergeValidate | None = None,
#   10856 ) -> DataFrame:
#   10857     from pandas.core.reshape.merge import merge
# > 10859     return merge(
#   10860         self,
#   10861         right,
#   10862         how=how,
#   10863         on=on,
#   10864         left_on=left_on,
#   10865         right_on=right_on,
# ...

# %%
df_final = df_final.merge(
    annex4,
    on="item_code",
    how="left"
)

# %%
df_final.info()

# %%
df_final.head()

# %%
df_final["category_name"].value_counts()

# %%
df_final.to_csv("../outputs/final_analytics_dataset.csv", index=False)

# %%
annex1.head(), annex2.head(), annex3.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt

annex1 = pd.read_csv("../data/processed/annex1_cleaned.csv")
annex2 = pd.read_csv("../data/processed/annex2_cleaned.csv")
annex3 = pd.read_csv("../data/processed/annex3_cleaned.csv")
